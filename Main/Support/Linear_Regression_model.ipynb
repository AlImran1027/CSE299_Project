# %% [markdown]
# <a href="https://colab.research.google.com/github/AlImran1027/CSE299_Project/blob/main/Linear_Regression_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
dataset = pd.read_csv('Cardiovascular_Disease_Dataset.csv')
X = dataset.iloc[ :, 1:-1].values
y = dataset.iloc[ :, -1].values

# %%
dataset.shape
# Out:
# (1000, 14)

# %%
dataset.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels  target
# 0      3                 3       1
# 1      1                 1       0
# ...

# %%
# Get feature names from the original dataset (skip 'patientid' and 'target')
feature_names = dataset.columns[1:-1].tolist()

# Histogram of Target Variable
plt.figure(figsize=(6, 4))
plt.hist(y, bins=2, color="blue", alpha=0.7, edgecolor="black")
plt.xticks([0, 1], labels=["No Disease", "Disease"])
plt.xlabel("Heart Disease")
plt.ylabel("Count")
plt.title("Heart Disease Distribution")
plt.show()

# Feature Distributions (First 4 Features)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.ravel()  # Flatten axes array

# Convert X to DataFrame for easier column access
X_df = pd.DataFrame(X, columns=feature_names)

for i in range(4):  # First 4 features
    axes[i].hist(X_df.iloc[:, i], bins=20, color="green", alpha=0.7, edgecolor="black")
    axes[i].set_title(f"Feature: {feature_names[i]}")
    axes[i].set_xlabel("Value")
    axes[i].set_ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
print(X.shape)
# Out:
# (1000, 12)

# %%
print(X)
# Out:
# [[53.   1.   2.  ...  5.3  3.   3. ]
#  [40.   1.   0.  ...  3.7  1.   1. ]
#  [49.   1.   2.  ...  5.   1.   0. ]
#  ...
#  [69.   1.   0.  ...  1.4  3.   1. ]
#  [45.   1.   1.  ...  5.9  3.   2. ]
#  [25.   1.   0.  ...  4.7  0.   0. ]]

# %%
dataset.isnull().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2 , random_state=0 )

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(x_test)
np.set_printoptions(precision=2)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[ 1.02  1.  ]
#  [ 0.79  1.  ]
#  [ 1.01  1.  ]
#  [ 0.05  0.  ]
#  [ 0.72  1.  ]
#  [ 0.19  0.  ]
#  [ 0.74  1.  ]
#  [ 0.25  0.  ]
#  [ 1.3   1.  ]
#  [ 0.74  1.  ]
#  [ 0.82  1.  ]
#  [ 0.9   1.  ]
#  [-0.12  0.  ]
#  [ 0.74  1.  ]
#  [-0.13  0.  ]
#  [ 0.76  1.  ]
#  [ 1.29  1.  ]
#  [ 1.02  1.  ]
#  [ 0.27  0.  ]
#  [ 0.3   0.  ]
#  [ 0.03  0.  ]
#  [ 0.41  0.  ]
#  [-0.06  0.  ]
#  [ 1.19  1.  ]
#  [ 0.69  1.  ]
#  [-0.05  0.  ]
#  [ 0.35  0.  ]
#  [ 0.95  1.  ]
#  [ 0.94  1.  ]
#  [ 0.14  0.  ]
#  [ 0.26  0.  ]
#  [ 0.23  0.  ]
#  [ 0.87  1.  ]
#  [ 1.27  1.  ]
#  [ 1.05  1.  ]
#  [ 0.62  1.  ]
#  [ 1.35  1.  ]
#  [ 0.13  0.  ]
#  [ 0.06  0.  ]
#  [ 0.63  1.  ]
#  [ 0.25  0.  ]
#  [ 0.53  0.  ]
#  [ 0.81  1.  ]
#  [ 0.26  0.  ]
#  [ 1.34  1.  ]
#  [ 1.05  1.  ]
#  [ 0.07  0.  ]
#  [ 0.09  0.  ]
#  [ 0.25  0.  ]
#  [ 0.65  1.  ]
#  [-0.08  0.  ]
#  [ 0.27  0.  ]
#  [ 0.66  1.  ]
#  [ 0.74  1.  ]
#  [ 0.39  0.  ]
#  [ 0.85  1.  ]
#  [ 1.24  1.  ]
#  [-0.11  0.  ]
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred_binary = np.logical_and(0.6 < y_pred, y_pred < 1.2 )
# Compute evaluation metrics
accuracy = accuracy_score(y_test, y_pred_binary)
precision = precision_score(y_test, y_pred_binary)
recall = recall_score(y_test, y_pred_binary)
f1 = f1_score(y_test, y_pred_binary)

# Print the results
print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1-score: {f1:.4f}")
# Out:
# Accuracy: 0.9050
# Precision: 0.9778
# Recall: 0.8381
# F1-score: 0.9026

# %%
# Metrics and their values
metrics = ['Accuracy', 'Precision', 'Recall', 'F1-Score']
values = [accuracy, precision, recall, f1]

# Create a bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(metrics, values, color=['blue', 'orange', 'green', 'red'])

# Add value labels on top of bars
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height,
             f'{height:.2f}',
             ha='center', va='bottom')

# Customize the plot
plt.ylim(0, 1.0)  # Metrics range from 0 to 1
plt.title('Model Performance Metrics', fontsize=14)
plt.ylabel('Score', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
